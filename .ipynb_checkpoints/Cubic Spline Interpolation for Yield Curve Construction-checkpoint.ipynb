# %% [markdown]
# ### Load, clean and construct initial Duration and YtM Data

# %%
from scipy.interpolate import CubicSpline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

row = [0,4]
durations = [0.25, 0.5, 1, 2, 3, 5, 7, 10, 30]

def p2f(x):
    return float(x.strip('%'))/100

three_m = pd.read_csv('3M.csv', usecols= ['Date', 'Close'], skiprows = lambda x : x not in row, converters={'Close':p2f})
six_m = pd.read_csv('6M.csv', usecols= ['Date', 'Close'], skiprows = lambda x : x not in row, converters={'Close':p2f})
one_y = pd.read_csv('1Y.csv', usecols= ['Date', 'Close'], skiprows = lambda x : x not in row, converters={'Close':p2f})
two_y = pd.read_csv('2Y.csv', usecols= ['Date', 'Close'], skiprows = lambda x : x not in row, converters={'Close':p2f})
three_y = pd.read_csv('3Y.csv', usecols= ['Date', 'Close'], skiprows = lambda x : x not in row, converters={'Close':p2f})
five_y = pd.read_csv('5Y.csv', usecols= ['Date', 'Close'], skiprows = lambda x : x not in row, converters={'Close':p2f})
seven_y = pd.read_csv('7Y.csv', usecols= ['Date', 'Close'], skiprows = lambda x : x not in row, converters={'Close':p2f})
ten_y = pd.read_csv('10Y.csv', usecols= ['Date', 'Close'], skiprows = lambda x : x not in row,converters={'Close':p2f})
thirty_y = pd.read_csv('30Y.csv', usecols= ['Date', 'Close'], skiprows = lambda x : x not in row, converters={'Close':p2f})

x1 = np.array(three_m.Close)
x2 = np.append(x1, six_m.Close)
x3 = np.append(x2, one_y.Close)
x4 = np.append(x3, two_y.Close)
x5 = np.append(x4, three_y.Close)
x6 = np.append(x5, five_y.Close)
x7 = np.append(x6, seven_y.Close)
x8 = np.append(x7, ten_y.Close)

yields = np.append(x8, thirty_y.Close)

d = {'Duration': durations, 'Yield': yields}

data = pd.DataFrame(data=d)
data
# Out:
#    Duration    Yield
# 0      0.25  0.05408
# 1      0.50  0.05513
# 2      1.00  0.05402
# 3      2.00  0.04877
# 4      3.00  0.04562
# 5      5.00  0.04237
# 6      7.00  0.04118
# 7     10.00  0.03974
# 8     30.00  0.04012

# %%
f = CubicSpline(durations, yields, bc_type="natural")
xvals = np.linspace(0,30,121)
interpolate_y = f(xvals)

interpolated_raw = {'Duration': xvals, 'Yield': interpolate_y}

inter_data = pd.DataFrame(data=interpolated_raw)
inter_data
# Out:
#      Duration     Yield
# 0        0.00  0.053030
# 1        0.25  0.054080
# 2        0.50  0.055130
# 3        0.75  0.055010
# 4        1.00  0.054020
# ..        ...       ...
# 116     29.00  0.039868
# 117     29.25  0.039931
# 118     29.50  0.039994
# 119     29.75  0.040057
# 120     30.00  0.040120
#
# [121 rows x 2 columns]

# %%
cds = 0.0049

# %%
anchor_points = [1,2,3,4,8,12,20,28,40,60,80,100]

durations_to_interpolate = []
yields_to_interpolate = []

for i in anchor_points:
    durations_to_interpolate.append(inter_data.Duration[i])
    yields_to_interpolate.append(inter_data.Yield[i]+cds)

durs = np.array(durations_to_interpolate)
yields = np.array(yields_to_interpolate)

e = {'Duration': durs, 'Yield': yields}

df = pd.DataFrame(data=e)
to_spline = df.copy()
to_spline['RF'] = round(df['Yield']*100, 5)
df
# Out:
#     Duration     Yield
# 0       0.25  0.058980
# 1       0.50  0.060030
# 2       0.75  0.059910
# 3       1.00  0.058920
# 4       2.00  0.053670
# 5       3.00  0.050520
# 6       5.00  0.047270
# 7       7.00  0.046080
# 8      10.00  0.044640
# 9      15.00  0.043203
# 10     20.00  0.043079
# 11     25.00  0.043831

# %%
durations_to_interpolate = np.array(to_spline.Duration)
yields_to_interpolate = np.array(to_spline.Yield)
rf = np.array(to_spline.RF)

f = CubicSpline(durations_to_interpolate, yields_to_interpolate, bc_type="natural")

x_space = np.linspace(0.25, 25, 100)
y_splined = f(x_space)

new_space = {'Period': x_space, 'Interest': y_splined}
df1 = pd.DataFrame(data=new_space)
df1['RF'] = round(df1['Interest']*100,5)
df1
# Out:
#     Period  Interest       RF
# 0     0.25  0.058980  5.89800
# 1     0.50  0.060030  6.00300
# 2     0.75  0.059910  5.99098
# 3     1.00  0.058920  5.89200
# 4     1.25  0.057636  5.76358
# ..     ...       ...      ...
# 95   24.00  0.043649  4.36486
# 96   24.25  0.043694  4.36937
# 97   24.50  0.043739  4.37391
# 98   24.75  0.043785  4.37848
# 99   25.00  0.043831  4.38307
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

M0 = np.min(df1.RF) - 0.07
M1 = np.max(df1.RF) + 0.07

fontsize=13

fig, ax = plt.subplots(figsize=(13,7))

dur = [0.25, 0.5, 1., 2., 3., 5., 7., 10., 30.]
df1["Observed"] = df1["RF"].isin(dur)

sns.scatterplot(df = df1, x = "Period", y = "RF", hue = "Observed", ax = ax)
sns.lineplot(df = df1, x = "Period", y = "RF", ax = ax)

plt.xlabel('Period',fontsize=fontsize)
plt.ylabel('Yield',fontsize=fontsize)

plt.xlim(0, 25)
plt.ylim(M0, M1)
plt.legend(loc="center right")
plt.title("USD Treasury Bill Yield Curve - Cubic Spline Interpolation",fontsize=fontsize)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 14
#      11 dur = [0.25, 0.5, 1., 2., 3., 5., 7., 10., 30.]
#      12 df1["Observed"] = df1["RF"].isin(dur)
# ---> 14 sns.scatterplot(df = df1, x = "Period", y = "RF", hue = "Observed", ax = ax)
#      15 sns.lineplot(df = df1, x = "Period", y = "RF", ax = ax)
#      17 plt.xlabel('Period',fontsize=fontsize)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\seaborn\relational.py:742, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     732 def scatterplot(
#     733     data=None, *,
#     734     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     738     **kwargs
#     739 ):
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     745     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\seaborn\relational.py:538, in _ScatterPlotter.__init__(self, data, variables, legend)
#     529 def __init__(self, *, data=None, variables={}, legend=None):
#     530
#     531     # TODO this is messy, we want the mapping to be agnostic about
#     532     # the kind of plot to draw, but for the time being we need to set
#     533     # this information so the SizeMapping can use it
#     534     self._default_size_range = (
#     535         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     536     )
# --> 538     super().__init__(data=data, variables=variables)
#     540     self.legend = legend
#
# File ~\AppData\Roaming\Python\Python38\site-packages\seaborn\_oldcore.py:640, in VectorPlotter.__init__(self, data, variables)
#     635 # var_ordered is relevant only for categorical axis variables, and may
#     636 # be better handled by an internal axis information object that tracks
#     637 # such information and is set up by the scale_* methods. The analogous
#     638 # information for numeric axes would be information about log scales.
#     639 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640 self.assign_variables(data, variables)
#     642 for var, cls in self._semantic_mappings.items():
#     643
#     644     # Create the mapping function
#     645     map_func = partial(cls.map, plotter=self)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\seaborn\_oldcore.py:701, in VectorPlotter.assign_variables(self, data, variables)
#     699 else:
#     700     self.input_format = "long"
# --> 701     plot_data, variables = self._assign_variables_longform(
#     702         data, **variables,
#     703     )
#     705 self.plot_data = plot_data
#     706 self.variables = variables
#
# File ~\AppData\Roaming\Python\Python38\site-packages\seaborn\_oldcore.py:938, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     933 elif isinstance(val, (str, bytes)):
#     934
#     935     # This looks like a column name but we don't know what it means!
#     937     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 938     raise ValueError(err)
#     940 else:
#     941
#     942     # Otherwise, assume the value is itself data
#     943
#     944     # Raise when data object is present and a vector can't matched
#     945     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `Period` for parameter `x`
